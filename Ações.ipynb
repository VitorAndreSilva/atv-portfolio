# %% [markdown]
# <a href="https://colab.research.google.com/github/VitorAndreSilva/atv-portfolio/blob/main/A%C3%A7%C3%B5es.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import yfinance as yf
itau = yf.download('ITUB4.SA', start = '2024-08-06')
itau.Close.plot();
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
import yfinance as yf
totvs = yf.download('TOTS3.SA', start = '2024-08-06')
totvs.Close.plot();
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
import yfinance as yf
weg = yf.download('WEGE3.SA', start = '2023-07-01')
weg.Close.plot();
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
import yfinance as yf
coca = yf.download('KO', start = '2024-08-06')
coca.Close.plot();
# Out:
# [*********************100%***********************]  1 of 1 completed
